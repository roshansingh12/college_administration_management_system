# %%
books_list=[]
complaints_list=[]
students_list=[]
notice_list=[]
course_list=[]
staff_list=[]
teachers_list=[]

# %%
class teacher:
  def __init__(self,t_name,t_id):
    self.t_name=t_name
    self.t_id=t_id
  def add(self,t_name,t_id):
    ob=teacher(t_name,t_id)
    teachers_list.append(ob)
  def update(self,t_id,name,T_id):
    i=t_obj.search(t_id)
    teachers_list[i].t_id=T_id
    teachers_list[i].t_name=name
  def search(self, t_id): 
        for i in range(teachers_list.__len__()): 
            if (teachers_list[i].t_id == t_id): 
                return i
  def check(self,name,id):
        found=True
        for i in range(teachers_list.__len__()):
          if teachers_list[i].t_id==id:
            if teachers_list[i].t_name==name:
              print('log in succesful \n welcome {}'.format(name))
              pass
            else:
              name=input('enter name again : \n')
              t_obj.check(name,id)
              found=False
        if found==True:
          t_obj.operation()
        else:
          name=input('enter name again : \n')
          id=input('enter id again : \n')
          t_obj.check(name,id)
  def operation(self):
    x=int(input('enter : \n 1 to view students list \n 2 to view books \n 3 to view notices \n 4 to logout \n 0 to exit'))
    if x==1:
      st_obj.view()
    elif x==2:
      b_obj.view()
    elif x==3:
      notice_obj.view()
    elif x==4:
      print('you have been logged out')
      start=Auth()
      return None
    elif x==0:
      print('you exit')
      return None
      exit(0)
    t_obj.operation()
 
 
 
class staff:
  def __init__(self,s_name,s_id):
    self.s_name=s_name
    self.s_id=s_id
  def add(self,s_name,s_id):
    ob=staff(s_name,s_id)
    staff_list.append(ob)
  def update(self,s_id,name,S_id):
    try:
      i=s_obj.search(s_id)
      staff_list[i].s_id=S_id
      staff_list[i].s_name=name
    except Exception:
      print('staff member do not exist.')
      return None
  def search(self, s_id):
        for i in range(staff_list.__len__()): 
            if (staff_list[i].s_id == s_id): 
                return i
 
class course:
  def __init__(self,c_name,c_id,teacher_name,teacher_id):
    self.c_name=c_name
    self.c_id=c_id
    self.teacher_name=teacher_name
    self.teacher_id=teacher_id
  def add(self,c_name,c_id,t_id):
    try:
      i=t_obj.search(t_id)
      teacher_name=teachers_list[i].t_name
      teacher_id=teachers_list[i].t_id
      ob=course(c_name,c_id,teacher_name,teacher_id)
      course_list.append(ob)
    except Exception:
      print('teacher not exist :')
      return None
  def update(self,c_id,name,C_id,t_id):
    i=c_obj.search(c_id)
    course_list[i].c_id=C_id
    course_list[i].c_name=name
    j=t_obj.search(t_id)
    teacher_name=teachers_list[j].t_name
    teacher_id=teachers_list[j].t_id
    course_list[i].teacher_name=teacher_name
    course_list[i].teacher_id=teacher_id
  def search(self, c_id): 
        for i in range(course_list.__len__()): 
            if (staff_list[i].c_id == c_id): 
                return i
  
class Notice:
  def __init__(self,notice):
    self.notice=notice
  def add(self,notice):
    ob=Notice(notice)
    notice_list.append(ob)
  def view(self):
    for i in range(notice_list.__len__()):
      print(notice_list[i].notice)
 
 
class admin:
  def __init__(self):
    self.name='admin_name'
    self.pwd='admin_password'
  def check(self,name,pwd):
    if self.name==name:
      if self.pwd==pwd:
        print('login successful')
        b=admin()
        b.operation()
        
      else:
        print('password is incorrect')
        pwd=input('Enter admin password : \n')
        admin.check(name,pwd)
    else:
        print('username is incorrect')
        name=input('Enter admin username : \n')
        admin.check(name,pwd)
  def operation(self):
      x=int(input('enter : \n 1 to add teacher \n 2 to update teacher details \n 3 to add school staff  \n 4 to update staff details  \n 5 to add course  \n 6 to update course \n 7 to  add notices \n 8 to log out \n 0 to exit : \n'))      
      if x==0:
        print('you exit')
        return 'exit'
        exit(0)
 
      if x==1:
          teacher_name=input('enter teacher name : \n')
          teacher_id=input('enter teacher id : \n')
          t_obj.add(teacher_name,teacher_id)
          
      elif x==2:
          t_id=input('enter teacher id : \n')
          name=input('enter new name : \n')
          T_id=input('enter new teacher id : \n')
          t_obj.update(t_id,name,T_id)
      elif x==3:
          member_name=input('enter staff member name : \n')
          member_id=input('enter staff member id : \n')
          s_obj.add(member_name,member_id)
      elif x==4:
          s_id=input('enter staff member id : \n')
          name=input('enter new name : \n')
          S_id=input('enter new staff member id : \n')
          s_obj.update(s_id,name,S_id)
      elif x==5:
          course_name=input('enter course name : \n')
          course_id=input('enter course id : \n')
          teacher_details=input("enter teacher's id assigned for this course : \n")
          c_obj.add(course_name,course_id,teacher_details)
      elif x==6:
          c_id=input('enter course id : \n')
          name=input('enter new course name : \n')
          C_id=input('enter new staff member id : \n')
          t_id=input('assign new teacher , enter teacher"s_id : \n')
          s_obj.update(c_id,name,C_id,t_id)
      elif x==7:
          notice=input('enter notice : \n')
          notice_obj.add(notice)
      elif x==8:
          print('you have been logged out')
          start=Auth()
          return None
      a=admin()
      a.operation()
class complaints:
  def __init__(self,complaint):
    self.complaint=complaint
  def add(self,complaint):
    ob=complaints(complaint)
    complaints_list.append(ob)
  def display(self):
    for i in range(complaints_list.__len__()):
      print(complaints_list[i].complaint)
    return None
 
 
 
class student:
  def __init__(self,student_name,student_rollno,student_class,student_section):
    self.student_name=student_name
    self.student_rollno=student_rollno
    self.student_class=student_class
    self.student_section=student_section
  def add(self,student_name,student_rollno,student_class,student_section):
    ob=student(student_name,student_rollno,student_class,student_section)
    students_list.append(ob)
  def search(self, student_rollno):
      found=False 
      for i in range(students_list.__len__()): 
          if (students_list[i].student_rollno == student_rollno):
                found=True
                return i
 
  def update(self,student_name,student_rollno,student_new_rollno,student_class,student_section):
    i=st_obj.search(student_rollno)
    students_list[i].student_rollno=student_new_rollno
    students_list[i].student_name=student_name
    students_list[i].student_class=student_class
    students_list[i].student_section=student_section
  def check(self,student_rollno):
    try:
      i = st_obj.search(student_rollno)
      print('{} login successful :> '.format(students_list[i].student_name))
      st_obj.operation()
    except Exception :
      x=input('enter : 1 to enter roll number again : \n press any number to exit from current event \n')
      if x==1:
        student_rollno=input('Enter : \n')
        st_obj.check(student_rollno)
      else:
        Auth()
      
  def operation(self):
    x=int(input('enter : \n 1 to check books available \n 2 to view notices \n 3 to rise a complaint \n 4 to logout \n 0 to exit \n '))
    if x==1:
      b_obj.view()
    elif x==2:
      notice_obj.view()
    elif x==3 :
      complaint=input('enter your complaint :< \n')
      comp.add(complaint)
    elif x==4:
      print('you have been logged out successfully ')
      start=Auth()
      return None
    elif x==0:
      print('you exit')
      return None
      exit(0)
    st_obj.operation()
  def view(self):
    for i in range(students_list.__len__()):
      print(students_list[i].student_rollno,students_list[i].student_name,students_list[i].student_class,students_list[i].student_section)
 
 
class administrator:
  def __init__(self):
    self.name='administrator_name'
    self.pwd='administrator_password'
  def check(self,name,pwd):
    if self.name==name:
      if self.pwd==pwd:
        print('login successful')
        b=administrator()
        b.operation()
        
      else:
        print('password is incorrect')
        pwd=input('Enter admin password : \n')
        b=administrator()
        b.check(name,pwd)
    else:
        print('username is incorrect')
        name=input('Enter admin username : \n')
        b=administrator()
        b.check(name,pwd)
  def operation(self):
    x=int(input('enter : \n 1 to add student \n 2 to update student details \n 3 to check student complaints \n 4 to check books available \n 0 to exit \n 5 to log out'))
    if x==1:
      student_name=input('enter student name : \n')
      student_rollno=input('enter student roll number : \n')
      student_class=input('enter student class : \n')
      student_section = input('enter student section : \n')
      st_obj.add(student_name,student_rollno,student_class,student_section)
    elif x==2:
      student_rollno=input('enter student roll number you want to update : \n')
      student_name=input('enter new name of {} : \n'.format(student_rollno))
      student_new_rollno=input('enter new roll no. of {} : \n'.format(student_name))
      student_class=input('enter  new class of {} : \n'.format(student_name))
      student_section = input('enter new section of : {} : \n'.format(student_name))
      st_obj.update(student_name,student_rollno,student_new_rollno,student_class,student_section)
    elif x==3:
      comp.display()
    elif x==4:
      b_obj.view()
    elif x==0:
      print('you exit')
      return None
      exit(0)
    elif x==5:
      print('you have been logged out')
      start=Auth()
      return None
      exit(0)
 
    b=administrator()
    b.operation()
 
 
 
 
class library:
  def __init__(self,book):
    self.book=book
  def add(self,book):
    ob=library(book)
    books_list.append(ob)
  def view(self):
    for i in range(books_list.__len__()):
      print(books_list[i].book)
  def search(self,book):
    for i in range(books_list.__len__()):
      if books_list[i].book==book:
        return i
  def delete(self,book):
    i=b_obj.search(book)
    del books_list[i]
class librarian:
  def __init__(self):
    self.name='lib_name'
    self.pwd='lib_pwd'
  def check(self,name,pwd):
    if self.name==name and self.pwd==pwd:
      print('login Successful')
      lib_obj.operation()
    else:
      print('wrong password or name ')
      x=int(input('enter :\n 0 to exit \n and 1 to continue \n'))
      if x==0:
        return None
      else:
        name=input('name :\n')
        pwd=input('password : \n')
        x=lib_obj.check(name,pwd)
  def operation(self):
      x=int(input('enter : \n 1 to add books \n 2 to view books \n 3 to delete book \n 4 to log out \n 0 to exit \n'))
      if x==0:
        return None
        exit(0)
      elif x==4:
        print('you have been logged out')
        start=Auth()
        return None
        exit(0)
      elif x==1:
        book=input('enter book name : \n')
        x=b_obj.add(book)
      elif x==2:
        x=b_obj.view()
      elif x==3:
        book=input('enter book name you want to delete : \n ')
        x=b_obj.delete(book)
      a=lib_obj.operation()
 
 
      
 
lib_obj=librarian()
b_obj=library('0')
comp=complaints('0')
st_obj=student('0','0','0','0')
notice_obj=Notice('0')
c_obj=course('0','0','0','0')
s_obj=staff('0','0')
t_obj=teacher('0','0')
 
def Auth():
  x=int(input('enter : \n 1 for admin login \n 2 for administrator login \n 3 for teacher login \n 4 for student login \n 5 for librarian login  \n'))
  if x==1:
      name=input('Enter admin username : \n')
      pwd=input('Enter admin password : \n')
      a= admin()
      a.check(name,pwd)
  elif x==2:
      name=input('Enter administrator username : \n')
      pwd=input('Enter administrator password : \n')
      b=administrator()
      b.check(name,pwd)
  elif x==3:
    t_name=input('enter teacher name : \n')
    t_id=input('enter teacher id : \n')
    print(t_name,t_id)
    t_obj.check(t_name,t_id)
  elif x==4:
    student_rollno=input('enter you roll no. \n')
    #s=student()
    st_obj.check(student_rollno)
  elif x==5:
    name=input('enter name : \n')
    pwd=input('enter password : \n')
    lib_obj.check(name,pwd)
  else:
    return None
start=Auth()
# Out:
# enter :
#  1 for admin login
#  2 for administrator login
#  3 for teacher login
#  4 for student login
#  5 for librarian login
# 1
# Enter admin username :
# admin_name
# Enter admin password :
# admin_password
# login successful
# enter :
#  1 to add teacher
#  2 to update teacher details
#  3 to add school staff
#  4 to update staff details
#  5 to add course
#  6 to update course
#  7 to  add notices
#  8 to log out
#  0 to exit :
# 1
# enter teacher name :
# t1
# enter teacher id :
# t1
# enter :
#  1 to add teacher
#  2 to update teacher details
#  3 to add school staff
#  4 to update staff details
#  5 to add course
#  6 to update course
#  7 to  add notices
#  8 to log out
#  0 to exit :
# 3
# enter staff member name :
# s1
# enter staff member id :
# s1
# enter :
#  1 to add teacher
#  2 to update teacher details
#  3 to add school staff
#  4 to update staff details
#  5 to add course
#  6 to update course
#  7 to  add notices
#  8 to log out
#  0 to exit :
# 5
# ...
